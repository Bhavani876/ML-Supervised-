# %% [markdown]
# # Task 1

# %% [markdown]
# # Import required pyton libraries

# %%
#1
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
import sklearn.metrics as me
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import data from the data source

# %%
#2
df=pd.read_csv('DS2_C6_S1_Insurance_Data_Challenge.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Task 2

# %% [markdown]
# # Check the structure of data

# %%
#1
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # Summarise the data

# %%
#2
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %% [markdown]
# # Task 3

# %% [markdown]
# # Finding the missing value

# %%
#1
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
def num_cat(a):
    for i in a.columns:
        if a[i].nunique()<10:
            print(i,a[i].unique())

# %%
num_cat(df)
# Out:
# sex ['female' 'male']
# children [0 1 3 2 5 4]
# smoker ['yes' 'no']
# region ['southwest' 'southeast' 'northwest' 'northeast']

# %% [markdown]
# # Task 4

# %% [markdown]
# # Finding Label Encoder Technique

# %%
#1
df['sex']=df['sex'].astype('category')
df['smoker']=df['smoker'].astype('category')
df['region']=df['region'].astype('category')
df
# Out:
#       age sex     bmi  children smoker region      charges
# 0      19   0  27.900         0      1      3  16884.92400
# 1      18   1  33.770         1      0      2   1725.55230
# 2      28   1  33.000         3      0      2   4449.46200
# 3      33   1  22.705         0      0      1  21984.47061
# 4      32   1  28.880         0      0      1   3866.85520
# ...   ...  ..     ...       ...    ...    ...          ...
# 1333   50   1  30.970         3      0      1  10600.54830
# 1334   18   0  31.920         0      0      0   2205.98080
# 1335   18   0  36.850         0      0      2   1629.83350
# 1336   21   0  25.800         0      0      3   2007.94500
# 1337   61   0  29.070         0      1      1  29141.36030
#
# [1338 rows x 7 columns]

# %%
#2
x=preprocessing.LabelEncoder()
df['sex']=x.fit_transform(df['sex'])
df
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    0  27.900         0    yes  southwest  16884.92400
# 1      18    1  33.770         1     no  southeast   1725.55230
# 2      28    1  33.000         3     no  southeast   4449.46200
# 3      33    1  22.705         0     no  northwest  21984.47061
# 4      32    1  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    1  30.970         3     no  northwest  10600.54830
# 1334   18    0  31.920         0     no  northeast   2205.98080
# 1335   18    0  36.850         0     no  southeast   1629.83350
# 1336   21    0  25.800         0     no  southwest   2007.94500
# 1337   61    0  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=preprocessing.LabelEncoder()
df['smoker']=x.fit_transform(df['smoker'])
df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    0  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    0  31.920         0       0  northeast   2205.98080
# 1335   18    0  36.850         0       0  southeast   1629.83350
# 1336   21    0  25.800         0       0  southwest   2007.94500
# 1337   61    0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=preprocessing.LabelEncoder()
df['region']=x.fit_transform(df['region'])
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Data Scaling

# %%
#3
def feature_scaling(scale):
    new_df=df.select_dtypes(exclude=['object','category'])
    if scale=='minmax':
        scaler=preprocessing.MinMaxScaler()
    else:
        scaler=preprocessing.standardscaler()
    scale_df=pd.DataFrame(scaler.fit_transform(new_df),columns=new_df.columns)
    return scale_df
final_df=feature_scaling('minmax')
final_df.head()
# Out:
#         age  sex       bmi  children  smoker    region   charges
# 0  0.021739  0.0  0.321227       0.0     1.0  1.000000  0.251611
# 1  0.000000  1.0  0.479150       0.2     0.0  0.666667  0.009636
# 2  0.217391  1.0  0.458434       0.6     0.0  0.666667  0.053115
# 3  0.326087  1.0  0.181464       0.0     0.0  0.333333  0.333010
# 4  0.304348  1.0  0.347592       0.0     0.0  0.333333  0.043816

# %% [markdown]
# # correlation

# %%
#4
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000 -0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208  1.000000

# %%
plt.figure(figsize=(20,10))
sb.heatmap(df.corr(),annot=True);

# %% [markdown]
# # Task 5

# %% [markdown]
# # Train_Test_Method

# %%
final_df.shape
# Out:
# (1338, 7)

# %%
splitting_data=final_df

# %%
t=int(1338*0.7)

# %%
x_train=splitting_data.iloc[:t,:]
x_train
# Out:
#           age  sex       bmi  children  smoker    region   charges
# 0    0.021739  0.0  0.321227       0.0     1.0  1.000000  0.251611
# 1    0.000000  1.0  0.479150       0.2     0.0  0.666667  0.009636
# 2    0.217391  1.0  0.458434       0.6     0.0  0.666667  0.053115
# 3    0.326087  1.0  0.181464       0.0     0.0  0.333333  0.333010
# 4    0.304348  1.0  0.347592       0.0     0.0  0.333333  0.043816
# ..        ...  ...       ...       ...     ...       ...       ...
# 931  0.456522  0.0  0.444983       0.2     0.0  1.000000  0.081669
# 932  0.608696  1.0  0.264730       1.0     0.0  1.000000  0.143261
# 933  0.586957  0.0  0.520312       0.0     0.0  1.000000  0.099384
# 934  0.304348  1.0  0.570891       0.4     0.0  0.666667  0.056690
# 935  0.891304  0.0  0.310465       0.0     0.0  1.000000  0.177370
#
# [936 rows x 7 columns]

# %%
x_test=splitting_data.iloc[t+1:,:]
x_test
# Out:
#            age  sex       bmi  children  smoker    region   charges
# 937   0.456522  0.0  0.222357       1.0     0.0  0.333333  0.125205
# 938   0.000000  1.0  0.274953       0.4     0.0  0.666667  0.018869
# 939   0.760870  1.0  0.363734       0.0     0.0  0.666667  0.133535
# 940   0.000000  1.0  0.195050       0.0     0.0  0.666667  0.000000
# 941   0.695652  0.0  0.810600       0.2     0.0  0.666667  0.134523
# ...        ...  ...       ...       ...     ...       ...       ...
# 1333  0.695652  1.0  0.403820       0.6     0.0  0.333333  0.151299
# 1334  0.000000  0.0  0.429379       0.0     0.0  0.000000  0.017305
# 1335  0.000000  0.0  0.562012       0.0     0.0  0.666667  0.008108
# 1336  0.065217  0.0  0.264730       0.0     0.0  1.000000  0.014144
# 1337  0.934783  0.0  0.352704       0.0     1.0  0.333333  0.447249
#
# [401 rows x 7 columns]

# %% [markdown]
# # Bulit_in_method

# %%
#2
x=final_df
y=final_df['charges']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=80)

# %%
x_test
# Out:
#            age  sex       bmi  children  smoker    region   charges
# 240   0.108696  0.0  0.557170       0.4     1.0  0.000000  0.596818
# 651   0.760870  0.0  0.635997       0.2     0.0  0.666667  0.150967
# 761   0.108696  1.0  0.517622       0.2     0.0  1.000000  0.020672
# 836   0.391304  1.0  0.418079       0.0     0.0  1.000000  0.052361
# 1147  0.043478  0.0  0.429379       0.0     0.0  0.333333  0.018192
# ...        ...  ...       ...       ...     ...       ...       ...
# 410   0.021739  1.0  0.040893       0.0     0.0  0.333333  0.007973
# 932   0.608696  1.0  0.264730       1.0     0.0  1.000000  0.143261
# 195   0.021739  1.0  0.393597       0.0     0.0  0.333333  0.008263
# 1061  0.847826  1.0  0.322303       0.2     0.0  0.666667  0.166522
# 386   0.869565  0.0  0.621200       0.0     0.0  0.666667  0.171345
#
# [402 rows x 7 columns]

# %% [markdown]
# # Visualize for categorical data

# %%
plt.figure(figsize=(10,4))
a=df['region'].value_counts()
b=df['region'].unique()
plt.pie(a,labels=b,autopct='%.2f%%',explode=[0.3,0,0,0]);

# %%
plt.figure(figsize=(10,4))
sb.countplot(data=df,x=df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # Task 6

# %% [markdown]
# # Visualize for Numerical data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int32
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int32
#  5   region    1338 non-null   int32
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int32(3), int64(2)
# memory usage: 57.6 KB

# %%
numerics=['int64','int32','float64']
new_insurance_df=df.select_dtypes(include=numerics)
numeric_columns=new_insurance_df.columns
num_cols=4
bins=80
num_row=int(len(numeric_columns)/num_cols)+1
fig, axs=plt.subplots(num_cols,num_row,tight_layout=True,figsize=(20,10))
for col, ax in zip(numeric_columns,axs.flatten()[:len(numeric_columns)]):
    ax.hist(new_insurance_df,bins=bins,density=True)
    ax.set_title(col);
