# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score,RepeatedStratifiedKFold,StratifiedKFold,KFold
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("DS2_C5_S6_KCHouse_Data_Practice.csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # Task 1: Data Prepartion and sampling.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  int32
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  int32
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  int32
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  int32
#  16  long           21613 non-null  int32
#  17  sqft_living15  21613 non-null  int64
# ...

# %%
df.isnull().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
plt.figure(figsize=(20,8))
sb.heatmap(df.corr(),annot=True,linecolor='k',linewidths=.5,cmap='Greys',center=0);

# %% [raw]
# #conclusion:- Having the high corrleation of price with sqrt_lot.

# %% [markdown]
# # Data Visulizations.

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].nunique()<10:
        cat.append(i)
    else:
        num.append(i)

# %%
cat
# Out:
# ['floors', 'waterfront', 'view', 'condition']

# %%
num
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
cat_cols=cat
num_col=2
num_rows=int(len(cat_cols)/num_col)
fig,axs=plt.subplots(num_rows,num_col,tight_layout=True,figsize=(20,8))
for col,ax in zip(cat_cols,axs.flatten()[:len(cat_cols)]):
    ax.pie(labels=df[col].value_counts().index,x=df[col].value_counts().values,autopct='%.2f%%')
    ax.set_title(col)

# %%
numeric_cols=num
num_col=4
bins=50
num_rows=int(len(numeric_cols)/num_col)
fig,axs=plt.subplots(num_rows,num_col,tight_layout=True,figsize=(20,8))
for col,ax in zip(numeric_cols,axs.flatten()[:len(cat_cols)]):
    ax.hist(df[col],bins=bins)
    ax.set_title(col)

# %%
df=df.drop(labels=['id','date'],axis=1)

# %%
#Feature scaling
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
df1=pd.DataFrame(scale.fit_transform(df),columns=df.columns)
df1
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# 0     -0.866717 -0.398737  -1.447464    -0.979835 -0.228321 -0.915427
# 1     -0.005688 -0.398737   0.175607     0.533634 -0.189885  0.936506
# 2     -0.980849 -1.473959  -1.447464    -1.426254 -0.123298 -0.915427
# 3      0.174090  0.676485   1.149449    -0.130550 -0.244014 -0.915427
# 4     -0.081958 -0.398737  -0.149007    -0.435422 -0.169653 -0.915427
# ...         ...       ...        ...          ...       ...       ...
# 21608 -0.490545 -0.398737   0.500221    -0.598746 -0.337424  2.788439
# 21609 -0.381588  0.676485   0.500221     0.250539 -0.224386  0.936506
# 21610 -0.375865 -1.473959  -1.772078    -1.154047 -0.332137  0.936506
# 21611 -0.381588 -0.398737   0.500221    -0.522528 -0.307076  0.936506
# 21612 -0.585882 -1.473959  -1.772078    -1.154047 -0.338752  0.936506
#
#        waterfront      view  condition     grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# # Splitting data.

# %%
x=df1.drop(columns='price',axis=1)
y=df1['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=8)

# %% [markdown]
# # Task 2: Baseline: Linear Regression.

# %% [markdown]
# # Evaluate a simple Linear Regression model as baseline.

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
model=LR.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.696763873899443

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([-0.22577502,  0.42336575, -1.07976611, ..., -1.05164112,
#         0.17893385, -0.85401732])

# %% [markdown]
# # Accuracy for the testing data.

# %%
model.fit(x_test,y_test)
model.score(x_train,y_train)
# Out:
# 0.6935958763556844

# %% [markdown]
# # Model Evaluation.

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 0.3062852048902703

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 0.33724375076570207

# %%
from sklearn.metrics import mean_absolute_error
RMSE=mean_squared_error(y_test,y_pred,squared=False)
RMSE
# Out:
# 0.5534303975119819

# %%
print('R_square',model.score(x_train,y_train))
print('MSE',MSE)
print('MAE',MAE)
print('RMSE',RMSE)
# Out:
# R_square 0.6935958763556844
# MSE 0.3062852048902703
# MAE 0.33724375076570207
# RMSE 0.5534303975119819

# %% [markdown]
# # Task 3: Bagging with Random Forest.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score,KFold
DT=RandomForestRegressor()
cv=KFold(n_splits=7)
score=cross_val_score(DT,x,y,scoring='neg_mean_squared_error',cv=cv)
print('mean.score',np.sqrt(-score).mean())
# Out:
# mean.score 0.35626764739039557

# %% [markdown]
# # Task 4: Evaluate the Best model and predict the test data.

# %% [markdown]
# # Evaluate the best model on the training and testing dataset.

# %%
model1=DT.fit(x_train,y_train)
model1.score(x_train,y_train)
# Out:
# 0.9822571831264889

# %%
y_pred1=model1.predict(x_test)
y_pred1
# Out:
# array([-0.11624072,  0.17967659, -0.94069249, ..., -0.89622332,
#         0.08863754, -0.91366541])

# %% [markdown]
# # Make a prediction on the test dataset.

# %%
model1=DT.fit(x_test,y_test)
model1.score(x_train,y_train)
# Out:
# 0.846046569998097

# %% [markdown]
# # Model Evaluation.

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_pred)
MSE
# Out:
# 0.3062852048902703

# %%
from sklearn.metrics import mean_absolute_error
MAE=mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 0.33724375076570207

# %%
from sklearn.metrics import mean_absolute_error
RMSE=mean_squared_error(y_test,y_pred,squared=False)
RMSE
# Out:
# 0.5534303975119819

# %%
print('R_square',model.score(x_train,y_train))
print('MSE',MSE)
print('MAE',MAE)
print('RMSE',RMSE)
# Out:
# R_square 0.6935958763556844
# MSE 0.3062852048902703
# MAE 0.33724375076570207
# RMSE 0.5534303975119819

# %% [markdown]
# # Plot original and prediction price values.

# %%
x_test.shape
# Out:
# (4323, 18)

# %%
plt.scatter(x=range(4323),y=y_pred,color='Green',label='prediction',s=0.1,marker='^')
plt.scatter(x=range(4323),y=y_pred,color='Red',label='Actual',s=0.1,marker='*')
plt.legend();

# %% [raw]
# # Linear Regression is the  Best model having its high accuracy.
